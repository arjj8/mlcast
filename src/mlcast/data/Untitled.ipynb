# %%
from pipeline_core import Pipeline
import xarray as xr
import fiddle as fdl

# %%
cfg = Pipeline()

# %%
cfg.steps[0].pars.output
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 cfg.steps[0].pars.output
#
# AttributeError: type object 'Tile_pars' has no attribute 'output'
